# %%
import pandas_datareader as pdr
import yfinance as yf
import pandas as pd

gdp = pdr.get_data_fred('GDP', start='2022-01-01')

# %%
gdp.tail(10)
# Out:
#                   GDP
# DATE
# 2022-01-01  25029.116
# 2022-04-01  25544.273
# 2022-07-01  25994.639
# 2022-10-01  26408.405
# 2023-01-01  26813.601
# 2023-04-01  27063.012
# 2023-07-01  27610.128
# 2023-10-01  27956.998
# 2024-01-01  28269.174

# %%
# Definir fechas
start_date = "2022-01-01"
end_date = "2024-06-30"

# Obtener datos del índice
sp500_data = yf.download("^SPX", start=start_date, end=end_date)

# Filtrar por fechas de inicio de trimestre
sp500_data["Month"] = sp500_data.index.month_name()
sp500_data["Quarter"] = sp500_data["Month"].apply(lambda x: int(x[0:1]))

qtr_start_data = sp500_data.groupby(["Year", "Quarter"]).last()

# Exportar a CSV
sp500_data.to_csv("output.csv", index=False)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# Filtrar por fechas de inicio de trimestre
sp500_data["Month"] = sp500_data.index.month_name()
sp500_data.head(35)
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-01-03  4778.140137  4796.640137  4758.169922  4796.560059  4796.560059
# 2022-01-04  4804.509766  4818.620117  4774.270020  4793.540039  4793.540039
# 2022-01-05  4787.990234  4797.700195  4699.439941  4700.580078  4700.580078
# 2022-01-06  4693.390137  4725.009766  4671.259766  4696.049805  4696.049805
# 2022-01-07  4697.660156  4707.950195  4662.740234  4677.029785  4677.029785
# 2022-01-10  4655.339844  4673.020020  4582.240234  4670.290039  4670.290039
# 2022-01-11  4669.140137  4714.129883  4638.270020  4713.069824  4713.069824
# 2022-01-12  4728.589844  4748.830078  4706.709961  4726.350098  4726.350098
# 2022-01-13  4733.560059  4744.129883  4650.290039  4659.029785  4659.029785
# 2022-01-14  4637.990234  4665.129883  4614.750000  4662.850098  4662.850098
# 2022-01-18  4632.240234  4632.240234  4568.700195  4577.109863  4577.109863
# ...

# %%
sp500_data["Quarter"] = sp500_data["Month"].apply(lambda x: int(x[0:1]))

sp500_data.head(35)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 sp500_data["Quarter"] = sp500_data["Month"].apply(lambda x: int(x[0:1]))
#       3 sp500_data.head(35)
#
# File ~\anaconda3\envs\data\Lib\site-packages\pandas\core\series.py:4764, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4629 def apply(
#    4630     self,
#    4631     func: AggFuncType,
#    (...)
#    4636     **kwargs,
#    4637 ) -> DataFrame | Series:
#    4638     """
#    4639     Invoke function on values of Series.
#    4640
#    (...)
#    4755     dtype: float64
#    4756     """
#    4757     return SeriesApply(
#    4758         self,
#    4759         func,
#    4760         convert_dtype=convert_dtype,
#    4761         by_row=by_row,
#    4762         args=args,
#    4763         kwargs=kwargs,
# -> 4764     ).apply()
#
# ...
